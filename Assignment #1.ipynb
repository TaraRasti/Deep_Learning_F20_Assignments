# %%
import time
import random
import sklearn
import torch
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
print("Scikit-learn Version: ", sklearn.__version__)
print("TensorFlow Version: ", tf.__version__)
print("PyTorch Version: ", torch.__version__)
# Out:
# Scikit-learn Version:  0.22.1
# TensorFlow Version:  2.3.0
# PyTorch Version:  1.6.0

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 5 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('A')
plt.ylabel('B')
plt.show()
df = pd.DataFrame(np.random.randn(10, 5)) 
print(df)
j=np.pi
for i in range(100000000):
  j+=j    
print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3         4
# 0 -1.381376  0.601618 -0.416658  0.097378  0.624859
# 1 -0.360543  0.619776 -1.495283 -0.402421  0.814716
# 2 -0.127202  0.034793 -1.254339  0.514965 -0.851154
# 3  0.784085  0.419143 -1.186560 -3.006298  1.288111
# 4 -1.170384  2.456924  0.075803  0.344454 -0.838001
# 5 -0.128104 -0.275839 -0.577102  1.575022  0.488845
# 6 -0.623141 -0.796522  0.513847 -1.185510 -0.403381
# 7  0.981411 -0.575867  0.342373 -0.544243  1.506965
# 8  0.434196  1.216412 -1.505338  0.061220 -0.363851
# 9 -1.205820  0.689039  0.361587 -0.154990 -0.784982
#
# -> Execution Time = 7.5472917556762695 in Seconds <-
