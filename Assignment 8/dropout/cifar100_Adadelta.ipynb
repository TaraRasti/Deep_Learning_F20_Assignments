# %% [markdown]
# <a href="https://colab.research.google.com/github/TaraRasti/Deep_Learning_F20_Assignments/blob/master/Assignment%208/dropout/cifar100_Adadelta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPool2D
from keras.layers.core import Dense,Activation,Dropout,Flatten
from keras.utils import np_utils
from keras import *
import tensorflow as tf
import os
from six.moves import cPickle as pickle
import platform
import numpy as np
 
def load_files(filenames):
    data = np.array([])
    labels = np.array([])
    for name in filenames:
        with open(name, 'rb') as f:
            mydict = pickle.load(f, encoding='latin1')
        label_func = lambda x: np.array(x['fine_labels'], dtype='int32')
        newlabels = label_func(mydict)
        if data.size:
            data = np.vstack([data, mydict['data']])
            labels = np.hstack([labels, newlabels])
        else:
            data = mydict['data']
            labels = newlabels
    data = np.reshape(data, [-1, 3, 32, 32], order='C')
    data = np.transpose(data, [0, 2, 3, 1])
    return data, labels

def load_CIFAR100(data_dir):
    train_files = ['train']
    train_files = [os.path.join(data_dir, f) for f in train_files]
    test_files = ['test']
    test_files = [os.path.join(data_dir, f) for f in test_files]
    num_classes = 100
    train_data, train_labels = load_files(train_files)
    test_data, test_labels = load_files(test_files)
    return train_data, train_labels, test_data, test_labels
 
def get_CIFAR100_data(val_size=2000):
    cifar100_dir = '/content/drive/MyDrive/cifar-100-python'
    x_train, y_train, x_test, y_test = load_CIFAR100(cifar100_dir)
    x_train, x_val = np.split(x_train,[x_train.shape[0]-val_size])
    y_train, y_val = np.split(y_train,[y_train.shape[0]-val_size])
    x_train = x_train.astype('float32')
    x_val = x_val.astype('float32')
    x_test = x_test.astype('float32')
    x_train /= 255
    x_val /= 255
    x_test /= 255
    return x_train, y_train, x_val, y_val, x_test, y_test
x_train, y_train, x_val, y_val, x_test, y_test = get_CIFAR100_data()
print('Train data shape: ', x_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', x_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', x_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (48000, 32, 32, 3)
# Train labels shape:  (48000,)
# Validation data shape:  (2000, 32, 32, 3)
# Validation labels shape:  (2000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
epochs =  200
verbose =  2
name = 'conv_clf'
x = input = keras.Input(shape=(32,32,3))
x = layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical")(input)
x = layers.experimental.preprocessing.RandomContrast(0.2)(x)
x = layers.experimental.preprocessing.RandomRotation(3)(x)
x = layers.Conv2D(64,4,activation='relu')(x)
x = layers.Conv2D(64,4,activation='relu',kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.MaxPool2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(128,3,activation='relu')(x)
x = layers.Conv2D(128,3,activation='relu',kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(256,3,activation='relu')(x)
x = layers.Conv2D(256,3,activation='relu',kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Flatten()(x)
x = layers.Dense(512,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(256,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
x = layers.Dropout(0.1)(x)
x = layers.Dense(128,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
output = layers.Dense(100,'softmax')(x)
model = keras.Model(inputs=input, outputs=output, name=name)
model.compile(loss=keras.losses.SparseCategoricalCrossentropy(),
            optimizer='Adadelta',
            metrics=['accuracy'])
model.fit(x = x_train, y = y_train,
          batch_size=64, epochs=epochs,
          verbose=verbose,validation_data=(x_val,y_val),
          validation_batch_size = 64)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0049s vs `on_train_batch_end` time: 0.0136s). Check your callbacks.
# 750/750 - 10s - loss: 4.9633 - accuracy: 0.0109 - val_loss: 4.7790 - val_accuracy: 0.0140
# Epoch 2/200
# 750/750 - 10s - loss: 4.8651 - accuracy: 0.0118 - val_loss: 4.7490 - val_accuracy: 0.0170
# Epoch 3/200
# 750/750 - 10s - loss: 4.7987 - accuracy: 0.0148 - val_loss: 4.6943 - val_accuracy: 0.0235
# Epoch 4/200
# 750/750 - 10s - loss: 4.7497 - accuracy: 0.0178 - val_loss: 4.6475 - val_accuracy: 0.0290
# Epoch 5/200
# 750/750 - 10s - loss: 4.7064 - accuracy: 0.0208 - val_loss: 4.6135 - val_accuracy: 0.0325
# Epoch 6/200
# 750/750 - 10s - loss: 4.6740 - accuracy: 0.0251 - val_loss: 4.5841 - val_accuracy: 0.0380
# Epoch 7/200
# 750/750 - 10s - loss: 4.6482 - accuracy: 0.0264 - val_loss: 4.5624 - val_accuracy: 0.0405
# Epoch 8/200
# 750/750 - 10s - loss: 4.6227 - accuracy: 0.0307 - val_loss: 4.5409 - val_accuracy: 0.0400
# Epoch 9/200
# 750/750 - 10s - loss: 4.6019 - accuracy: 0.0341 - val_loss: 4.5225 - val_accuracy: 0.0405
# Epoch 10/200
# 750/750 - 10s - loss: 4.5839 - accuracy: 0.0359 - val_loss: 4.5063 - val_accuracy: 0.0470
# Epoch 11/200
# 750/750 - 10s - loss: 4.5655 - accuracy: 0.0394 - val_loss: 4.4905 - val_accuracy: 0.0485
# Epoch 12/200
# 750/750 - 10s - loss: 4.5520 - accuracy: 0.0409 - val_loss: 4.4756 - val_accuracy: 0.0505
# Epoch 13/200
# 750/750 - 10s - loss: 4.5342 - accuracy: 0.0426 - val_loss: 4.4640 - val_accuracy: 0.0560
# Epoch 14/200
# 750/750 - 10s - loss: 4.5224 - accuracy: 0.0448 - val_loss: 4.4515 - val_accuracy: 0.0590
# Epoch 15/200
# 750/750 - 10s - loss: 4.5058 - accuracy: 0.0478 - val_loss: 4.4389 - val_accuracy: 0.0585
# Epoch 16/200
# 750/750 - 10s - loss: 4.4941 - accuracy: 0.0493 - val_loss: 4.4296 - val_accuracy: 0.0635
# Epoch 17/200
# 750/750 - 10s - loss: 4.4819 - accuracy: 0.0508 - val_loss: 4.4192 - val_accuracy: 0.0620
# Epoch 18/200
# 750/750 - 10s - loss: 4.4714 - accuracy: 0.0542 - val_loss: 4.4100 - val_accuracy: 0.0635
# Epoch 19/200
# 750/750 - 10s - loss: 4.4552 - accuracy: 0.0546 - val_loss: 4.3992 - val_accuracy: 0.0675
# Epoch 20/200
# 750/750 - 10s - loss: 4.4459 - accuracy: 0.0583 - val_loss: 4.3894 - val_accuracy: 0.0665
# Epoch 21/200
# 750/750 - 10s - loss: 4.4369 - accuracy: 0.0576 - val_loss: 4.3785 - val_accuracy: 0.0700
# Epoch 22/200
# 750/750 - 10s - loss: 4.4326 - accuracy: 0.0589 - val_loss: 4.3701 - val_accuracy: 0.0690
# Epoch 23/200
# 750/750 - 10s - loss: 4.4193 - accuracy: 0.0602 - val_loss: 4.3591 - val_accuracy: 0.0670
# Epoch 24/200
# 750/750 - 10s - loss: 4.4077 - accuracy: 0.0620 - val_loss: 4.3498 - val_accuracy: 0.0685
# Epoch 25/200
# 750/750 - 10s - loss: 4.3989 - accuracy: 0.0631 - val_loss: 4.3416 - val_accuracy: 0.0700
# Epoch 26/200
# 750/750 - 10s - loss: 4.3915 - accuracy: 0.0648 - val_loss: 4.3313 - val_accuracy: 0.0705
# Epoch 27/200
# 750/750 - 10s - loss: 4.3818 - accuracy: 0.0656 - val_loss: 4.3210 - val_accuracy: 0.0755
# Epoch 28/200
# 750/750 - 10s - loss: 4.3748 - accuracy: 0.0657 - val_loss: 4.3114 - val_accuracy: 0.0755
# Epoch 29/200
# 750/750 - 10s - loss: 4.3640 - accuracy: 0.0683 - val_loss: 4.3033 - val_accuracy: 0.0760
# Epoch 30/200
# 750/750 - 10s - loss: 4.3549 - accuracy: 0.0691 - val_loss: 4.2945 - val_accuracy: 0.0760
# Epoch 31/200
# 750/750 - 10s - loss: 4.3490 - accuracy: 0.0705 - val_loss: 4.2853 - val_accuracy: 0.0785
# Epoch 32/200
# 750/750 - 10s - loss: 4.3388 - accuracy: 0.0732 - val_loss: 4.2764 - val_accuracy: 0.0800
# Epoch 33/200
# 750/750 - 10s - loss: 4.3342 - accuracy: 0.0718 - val_loss: 4.2702 - val_accuracy: 0.0810
# Epoch 34/200
# 750/750 - 10s - loss: 4.3241 - accuracy: 0.0734 - val_loss: 4.2605 - val_accuracy: 0.0835
# Epoch 35/200
# 750/750 - 10s - loss: 4.3173 - accuracy: 0.0744 - val_loss: 4.2530 - val_accuracy: 0.0850
# Epoch 36/200
# 750/750 - 10s - loss: 4.3048 - accuracy: 0.0770 - val_loss: 4.2444 - val_accuracy: 0.0900
# Epoch 37/200
# 750/750 - 10s - loss: 4.3019 - accuracy: 0.0764 - val_loss: 4.2372 - val_accuracy: 0.0905
# Epoch 38/200
# 750/750 - 10s - loss: 4.2937 - accuracy: 0.0770 - val_loss: 4.2302 - val_accuracy: 0.0925
# Epoch 39/200
# 750/750 - 10s - loss: 4.2900 - accuracy: 0.0791 - val_loss: 4.2198 - val_accuracy: 0.0955
# Epoch 40/200
# 750/750 - 10s - loss: 4.2797 - accuracy: 0.0803 - val_loss: 4.2123 - val_accuracy: 0.0945
# Epoch 41/200
# 750/750 - 10s - loss: 4.2749 - accuracy: 0.0799 - val_loss: 4.2039 - val_accuracy: 0.0980
# Epoch 42/200
# 750/750 - 10s - loss: 4.2644 - accuracy: 0.0826 - val_loss: 4.1976 - val_accuracy: 0.0950
# Epoch 43/200
# 750/750 - 10s - loss: 4.2564 - accuracy: 0.0828 - val_loss: 4.1887 - val_accuracy: 0.1000
# Epoch 44/200
# 750/750 - 10s - loss: 4.2508 - accuracy: 0.0831 - val_loss: 4.1836 - val_accuracy: 0.0940
# Epoch 45/200
# 750/750 - 10s - loss: 4.2465 - accuracy: 0.0839 - val_loss: 4.1754 - val_accuracy: 0.0955
# Epoch 46/200
# 750/750 - 10s - loss: 4.2369 - accuracy: 0.0854 - val_loss: 4.1711 - val_accuracy: 0.0975
# Epoch 47/200
# 750/750 - 10s - loss: 4.2338 - accuracy: 0.0856 - val_loss: 4.1653 - val_accuracy: 0.1005
# Epoch 48/200
# 750/750 - 10s - loss: 4.2272 - accuracy: 0.0870 - val_loss: 4.1546 - val_accuracy: 0.0995
# Epoch 49/200
# 750/750 - 10s - loss: 4.2205 - accuracy: 0.0869 - val_loss: 4.1503 - val_accuracy: 0.1005
# Epoch 50/200
# 750/750 - 10s - loss: 4.2166 - accuracy: 0.0870 - val_loss: 4.1458 - val_accuracy: 0.1020
# Epoch 51/200
# 750/750 - 10s - loss: 4.2050 - accuracy: 0.0896 - val_loss: 4.1397 - val_accuracy: 0.1005
# Epoch 52/200
# 750/750 - 10s - loss: 4.2006 - accuracy: 0.0895 - val_loss: 4.1329 - val_accuracy: 0.1055
# Epoch 53/200
# 750/750 - 10s - loss: 4.1977 - accuracy: 0.0887 - val_loss: 4.1255 - val_accuracy: 0.1075
# Epoch 54/200
# 750/750 - 10s - loss: 4.1920 - accuracy: 0.0907 - val_loss: 4.1164 - val_accuracy: 0.1045
# Epoch 55/200
# 750/750 - 10s - loss: 4.1855 - accuracy: 0.0892 - val_loss: 4.1115 - val_accuracy: 0.1080
# Epoch 56/200
# 750/750 - 10s - loss: 4.1756 - accuracy: 0.0922 - val_loss: 4.1033 - val_accuracy: 0.1090
# Epoch 57/200
# 750/750 - 10s - loss: 4.1732 - accuracy: 0.0928 - val_loss: 4.0973 - val_accuracy: 0.1065
# Epoch 58/200
# 750/750 - 10s - loss: 4.1668 - accuracy: 0.0944 - val_loss: 4.0900 - val_accuracy: 0.1105
# Epoch 59/200
# 750/750 - 10s - loss: 4.1556 - accuracy: 0.0959 - val_loss: 4.0845 - val_accuracy: 0.1115
# Epoch 60/200
# 750/750 - 10s - loss: 4.1514 - accuracy: 0.0961 - val_loss: 4.0796 - val_accuracy: 0.1105
# Epoch 61/200
# 750/750 - 10s - loss: 4.1475 - accuracy: 0.0962 - val_loss: 4.0742 - val_accuracy: 0.1110
# Epoch 62/200
# 750/750 - 10s - loss: 4.1417 - accuracy: 0.0988 - val_loss: 4.0663 - val_accuracy: 0.1125
# Epoch 63/200
# 750/750 - 10s - loss: 4.1377 - accuracy: 0.0977 - val_loss: 4.0595 - val_accuracy: 0.1145
# Epoch 64/200
# 750/750 - 10s - loss: 4.1274 - accuracy: 0.0981 - val_loss: 4.0537 - val_accuracy: 0.1145
# Epoch 65/200
# 750/750 - 10s - loss: 4.1218 - accuracy: 0.0993 - val_loss: 4.0557 - val_accuracy: 0.1155
# Epoch 66/200
# 750/750 - 10s - loss: 4.1117 - accuracy: 0.1011 - val_loss: 4.0453 - val_accuracy: 0.1190
# Epoch 67/200
# 750/750 - 10s - loss: 4.1184 - accuracy: 0.1020 - val_loss: 4.0432 - val_accuracy: 0.1190
# Epoch 68/200
# 750/750 - 10s - loss: 4.1054 - accuracy: 0.1026 - val_loss: 4.0325 - val_accuracy: 0.1200
# Epoch 69/200
# 750/750 - 10s - loss: 4.0988 - accuracy: 0.1026 - val_loss: 4.0241 - val_accuracy: 0.1215
# Epoch 70/200
# 750/750 - 10s - loss: 4.0933 - accuracy: 0.1032 - val_loss: 4.0190 - val_accuracy: 0.1195
# Epoch 71/200
# 750/750 - 10s - loss: 4.0887 - accuracy: 0.1046 - val_loss: 4.0154 - val_accuracy: 0.1225
# Epoch 72/200
# 750/750 - 10s - loss: 4.0851 - accuracy: 0.1039 - val_loss: 4.0098 - val_accuracy: 0.1220
# Epoch 73/200
# 750/750 - 10s - loss: 4.0802 - accuracy: 0.1057 - val_loss: 4.0058 - val_accuracy: 0.1205
# Epoch 74/200
# 750/750 - 10s - loss: 4.0725 - accuracy: 0.1062 - val_loss: 3.9950 - val_accuracy: 0.1240
# Epoch 75/200
# 750/750 - 10s - loss: 4.0636 - accuracy: 0.1072 - val_loss: 3.9974 - val_accuracy: 0.1235
# Epoch 76/200
# 750/750 - 10s - loss: 4.0620 - accuracy: 0.1081 - val_loss: 3.9859 - val_accuracy: 0.1275
# Epoch 77/200
# 750/750 - 10s - loss: 4.0571 - accuracy: 0.1095 - val_loss: 3.9844 - val_accuracy: 0.1220
# Epoch 78/200
# 750/750 - 10s - loss: 4.0558 - accuracy: 0.1068 - val_loss: 3.9778 - val_accuracy: 0.1210
# Epoch 79/200
# 750/750 - 10s - loss: 4.0473 - accuracy: 0.1092 - val_loss: 3.9729 - val_accuracy: 0.1250
# Epoch 80/200
# 750/750 - 10s - loss: 4.0401 - accuracy: 0.1109 - val_loss: 3.9665 - val_accuracy: 0.1285
# Epoch 81/200
# 750/750 - 10s - loss: 4.0394 - accuracy: 0.1127 - val_loss: 3.9617 - val_accuracy: 0.1300
# Epoch 82/200
# 750/750 - 10s - loss: 4.0321 - accuracy: 0.1119 - val_loss: 3.9578 - val_accuracy: 0.1290
# Epoch 83/200
# 750/750 - 10s - loss: 4.0203 - accuracy: 0.1134 - val_loss: 3.9557 - val_accuracy: 0.1295
# Epoch 84/200
# 750/750 - 10s - loss: 4.0170 - accuracy: 0.1143 - val_loss: 3.9510 - val_accuracy: 0.1295
# Epoch 85/200
# 750/750 - 10s - loss: 4.0148 - accuracy: 0.1127 - val_loss: 3.9484 - val_accuracy: 0.1265
# Epoch 86/200
# 750/750 - 10s - loss: 4.0090 - accuracy: 0.1145 - val_loss: 3.9427 - val_accuracy: 0.1315
# Epoch 87/200
# 750/750 - 10s - loss: 4.0008 - accuracy: 0.1160 - val_loss: 3.9320 - val_accuracy: 0.1300
# Epoch 88/200
# 750/750 - 10s - loss: 3.9976 - accuracy: 0.1177 - val_loss: 3.9261 - val_accuracy: 0.1305
# Epoch 89/200
# 750/750 - 10s - loss: 3.9910 - accuracy: 0.1187 - val_loss: 3.9363 - val_accuracy: 0.1290
# Epoch 90/200
# 750/750 - 10s - loss: 3.9947 - accuracy: 0.1164 - val_loss: 3.9160 - val_accuracy: 0.1345
# Epoch 91/200
# 750/750 - 10s - loss: 3.9866 - accuracy: 0.1175 - val_loss: 3.9214 - val_accuracy: 0.1290
# Epoch 92/200
# 750/750 - 10s - loss: 3.9778 - accuracy: 0.1181 - val_loss: 3.9118 - val_accuracy: 0.1320
# Epoch 93/200
# 750/750 - 10s - loss: 3.9738 - accuracy: 0.1195 - val_loss: 3.9152 - val_accuracy: 0.1340
# Epoch 94/200
# 750/750 - 10s - loss: 3.9710 - accuracy: 0.1191 - val_loss: 3.9093 - val_accuracy: 0.1330
# Epoch 95/200
# 750/750 - 10s - loss: 3.9710 - accuracy: 0.1205 - val_loss: 3.9028 - val_accuracy: 0.1360
# Epoch 96/200
# 750/750 - 10s - loss: 3.9605 - accuracy: 0.1201 - val_loss: 3.8918 - val_accuracy: 0.1355
# Epoch 97/200
# 750/750 - 10s - loss: 3.9560 - accuracy: 0.1228 - val_loss: 3.8931 - val_accuracy: 0.1385
# Epoch 98/200
# 750/750 - 10s - loss: 3.9504 - accuracy: 0.1236 - val_loss: 3.8879 - val_accuracy: 0.1385
# Epoch 99/200
# 750/750 - 10s - loss: 3.9472 - accuracy: 0.1218 - val_loss: 3.8841 - val_accuracy: 0.1370
# Epoch 100/200
# 750/750 - 10s - loss: 3.9453 - accuracy: 0.1235 - val_loss: 3.8896 - val_accuracy: 0.1375
# Epoch 101/200
# 750/750 - 10s - loss: 3.9370 - accuracy: 0.1237 - val_loss: 3.8732 - val_accuracy: 0.1400
# Epoch 102/200
# 750/750 - 10s - loss: 3.9368 - accuracy: 0.1244 - val_loss: 3.8806 - val_accuracy: 0.1390
# Epoch 103/200
# 750/750 - 10s - loss: 3.9319 - accuracy: 0.1255 - val_loss: 3.8693 - val_accuracy: 0.1420
# Epoch 104/200
# 750/750 - 10s - loss: 3.9204 - accuracy: 0.1278 - val_loss: 3.8618 - val_accuracy: 0.1420
# Epoch 105/200
# 750/750 - 10s - loss: 3.9238 - accuracy: 0.1261 - val_loss: 3.8700 - val_accuracy: 0.1450
# Epoch 106/200
# 750/750 - 10s - loss: 3.9164 - accuracy: 0.1281 - val_loss: 3.8686 - val_accuracy: 0.1450
# Epoch 107/200
# 750/750 - 10s - loss: 3.9093 - accuracy: 0.1284 - val_loss: 3.8466 - val_accuracy: 0.1430
# Epoch 108/200
# 750/750 - 10s - loss: 3.9051 - accuracy: 0.1287 - val_loss: 3.8509 - val_accuracy: 0.1430
# Epoch 109/200
# 750/750 - 10s - loss: 3.9010 - accuracy: 0.1309 - val_loss: 3.8484 - val_accuracy: 0.1430
# Epoch 110/200
# 750/750 - 10s - loss: 3.8952 - accuracy: 0.1308 - val_loss: 3.8387 - val_accuracy: 0.1420
# Epoch 111/200
# 750/750 - 10s - loss: 3.8958 - accuracy: 0.1293 - val_loss: 3.8328 - val_accuracy: 0.1450
# Epoch 112/200
# 750/750 - 10s - loss: 3.8881 - accuracy: 0.1318 - val_loss: 3.8370 - val_accuracy: 0.1430
# Epoch 113/200
# 750/750 - 10s - loss: 3.8845 - accuracy: 0.1311 - val_loss: 3.8294 - val_accuracy: 0.1450
# Epoch 114/200
# 750/750 - 10s - loss: 3.8795 - accuracy: 0.1324 - val_loss: 3.8255 - val_accuracy: 0.1460
# Epoch 115/200
# 750/750 - 10s - loss: 3.8761 - accuracy: 0.1327 - val_loss: 3.8269 - val_accuracy: 0.1445
# Epoch 116/200
# 750/750 - 10s - loss: 3.8693 - accuracy: 0.1344 - val_loss: 3.8111 - val_accuracy: 0.1450
# Epoch 117/200
# 750/750 - 10s - loss: 3.8734 - accuracy: 0.1336 - val_loss: 3.8263 - val_accuracy: 0.1460
# Epoch 118/200
# 750/750 - 10s - loss: 3.8610 - accuracy: 0.1351 - val_loss: 3.8073 - val_accuracy: 0.1460
# Epoch 119/200
# 750/750 - 10s - loss: 3.8613 - accuracy: 0.1362 - val_loss: 3.8018 - val_accuracy: 0.1475
# Epoch 120/200
# 750/750 - 10s - loss: 3.8535 - accuracy: 0.1378 - val_loss: 3.8026 - val_accuracy: 0.1515
# Epoch 121/200
# 750/750 - 10s - loss: 3.8509 - accuracy: 0.1357 - val_loss: 3.7969 - val_accuracy: 0.1525
# Epoch 122/200
# 750/750 - 10s - loss: 3.8430 - accuracy: 0.1374 - val_loss: 3.7973 - val_accuracy: 0.1490
# Epoch 123/200
# 750/750 - 10s - loss: 3.8444 - accuracy: 0.1384 - val_loss: 3.7849 - val_accuracy: 0.1505
# Epoch 124/200
# 750/750 - 10s - loss: 3.8328 - accuracy: 0.1390 - val_loss: 3.7818 - val_accuracy: 0.1530
# Epoch 125/200
# 750/750 - 10s - loss: 3.8321 - accuracy: 0.1380 - val_loss: 3.7996 - val_accuracy: 0.1510
# Epoch 126/200
# 750/750 - 10s - loss: 3.8292 - accuracy: 0.1377 - val_loss: 3.7779 - val_accuracy: 0.1520
# Epoch 127/200
# 750/750 - 10s - loss: 3.8286 - accuracy: 0.1393 - val_loss: 3.7717 - val_accuracy: 0.1545
# Epoch 128/200
# 750/750 - 10s - loss: 3.8223 - accuracy: 0.1415 - val_loss: 3.7804 - val_accuracy: 0.1530
# Epoch 129/200
# 750/750 - 10s - loss: 3.8184 - accuracy: 0.1384 - val_loss: 3.7734 - val_accuracy: 0.1540
# Epoch 130/200
# 750/750 - 10s - loss: 3.8152 - accuracy: 0.1413 - val_loss: 3.7633 - val_accuracy: 0.1575
# Epoch 131/200
# 750/750 - 10s - loss: 3.8148 - accuracy: 0.1425 - val_loss: 3.7468 - val_accuracy: 0.1570
# Epoch 132/200
# 750/750 - 10s - loss: 3.8083 - accuracy: 0.1434 - val_loss: 3.7576 - val_accuracy: 0.1555
# Epoch 133/200
# 750/750 - 10s - loss: 3.8068 - accuracy: 0.1415 - val_loss: 3.7600 - val_accuracy: 0.1540
# Epoch 134/200
# 750/750 - 10s - loss: 3.8009 - accuracy: 0.1439 - val_loss: 3.7530 - val_accuracy: 0.1580
# Epoch 135/200
# 750/750 - 10s - loss: 3.7993 - accuracy: 0.1441 - val_loss: 3.7515 - val_accuracy: 0.1550
# Epoch 136/200
# 750/750 - 10s - loss: 3.7939 - accuracy: 0.1448 - val_loss: 3.7499 - val_accuracy: 0.1545
# Epoch 137/200
# 750/750 - 10s - loss: 3.7899 - accuracy: 0.1449 - val_loss: 3.7386 - val_accuracy: 0.1575
# Epoch 138/200
# 750/750 - 10s - loss: 3.7907 - accuracy: 0.1447 - val_loss: 3.7401 - val_accuracy: 0.1550
# Epoch 139/200
# 750/750 - 10s - loss: 3.7846 - accuracy: 0.1470 - val_loss: 3.7447 - val_accuracy: 0.1575
# Epoch 140/200
# 750/750 - 10s - loss: 3.7755 - accuracy: 0.1462 - val_loss: 3.7335 - val_accuracy: 0.1560
# Epoch 141/200
# 750/750 - 10s - loss: 3.7702 - accuracy: 0.1484 - val_loss: 3.7339 - val_accuracy: 0.1575
# Epoch 142/200
# 750/750 - 10s - loss: 3.7739 - accuracy: 0.1499 - val_loss: 3.7232 - val_accuracy: 0.1605
# Epoch 143/200
# 750/750 - 10s - loss: 3.7672 - accuracy: 0.1503 - val_loss: 3.7309 - val_accuracy: 0.1545
# Epoch 144/200
# 750/750 - 10s - loss: 3.7674 - accuracy: 0.1477 - val_loss: 3.7399 - val_accuracy: 0.1565
# Epoch 145/200
# 750/750 - 10s - loss: 3.7646 - accuracy: 0.1490 - val_loss: 3.7153 - val_accuracy: 0.1610
# Epoch 146/200
# 750/750 - 10s - loss: 3.7578 - accuracy: 0.1468 - val_loss: 3.7188 - val_accuracy: 0.1605
# Epoch 147/200
# 750/750 - 10s - loss: 3.7577 - accuracy: 0.1492 - val_loss: 3.7091 - val_accuracy: 0.1615
# Epoch 148/200
# 750/750 - 10s - loss: 3.7570 - accuracy: 0.1515 - val_loss: 3.7154 - val_accuracy: 0.1635
# Epoch 149/200
# 750/750 - 10s - loss: 3.7433 - accuracy: 0.1527 - val_loss: 3.7035 - val_accuracy: 0.1630
# Epoch 150/200
# 750/750 - 10s - loss: 3.7472 - accuracy: 0.1504 - val_loss: 3.7108 - val_accuracy: 0.1640
# Epoch 151/200
# 750/750 - 10s - loss: 3.7382 - accuracy: 0.1515 - val_loss: 3.7106 - val_accuracy: 0.1655
# Epoch 152/200
# 750/750 - 10s - loss: 3.7423 - accuracy: 0.1509 - val_loss: 3.6991 - val_accuracy: 0.1630
# Epoch 153/200
# 750/750 - 10s - loss: 3.7404 - accuracy: 0.1521 - val_loss: 3.6968 - val_accuracy: 0.1610
# Epoch 154/200
# 750/750 - 10s - loss: 3.7376 - accuracy: 0.1520 - val_loss: 3.6913 - val_accuracy: 0.1640
# Epoch 155/200
# 750/750 - 10s - loss: 3.7271 - accuracy: 0.1554 - val_loss: 3.7049 - val_accuracy: 0.1635
# Epoch 156/200
# 750/750 - 10s - loss: 3.7242 - accuracy: 0.1544 - val_loss: 3.6914 - val_accuracy: 0.1650
# Epoch 157/200
# 750/750 - 10s - loss: 3.7245 - accuracy: 0.1521 - val_loss: 3.6933 - val_accuracy: 0.1645
# Epoch 158/200
# 750/750 - 10s - loss: 3.7179 - accuracy: 0.1564 - val_loss: 3.6826 - val_accuracy: 0.1655
# Epoch 159/200
# 750/750 - 10s - loss: 3.7218 - accuracy: 0.1550 - val_loss: 3.6717 - val_accuracy: 0.1675
# Epoch 160/200
# 750/750 - 10s - loss: 3.7124 - accuracy: 0.1554 - val_loss: 3.6646 - val_accuracy: 0.1705
# Epoch 161/200
# 750/750 - 10s - loss: 3.7132 - accuracy: 0.1552 - val_loss: 3.6804 - val_accuracy: 0.1645
# Epoch 162/200
# 750/750 - 10s - loss: 3.7054 - accuracy: 0.1572 - val_loss: 3.6763 - val_accuracy: 0.1675
# Epoch 163/200
# 750/750 - 10s - loss: 3.7067 - accuracy: 0.1560 - val_loss: 3.6724 - val_accuracy: 0.1695
# Epoch 164/200
# 750/750 - 10s - loss: 3.6996 - accuracy: 0.1591 - val_loss: 3.6568 - val_accuracy: 0.1715
# Epoch 165/200
# 750/750 - 10s - loss: 3.7015 - accuracy: 0.1589 - val_loss: 3.6782 - val_accuracy: 0.1665
# Epoch 166/200
# 750/750 - 10s - loss: 3.6934 - accuracy: 0.1574 - val_loss: 3.6708 - val_accuracy: 0.1675
# Epoch 167/200
# 750/750 - 10s - loss: 3.6917 - accuracy: 0.1591 - val_loss: 3.6554 - val_accuracy: 0.1715
# Epoch 168/200
# 750/750 - 10s - loss: 3.6902 - accuracy: 0.1605 - val_loss: 3.6690 - val_accuracy: 0.1680
# Epoch 169/200
# 750/750 - 10s - loss: 3.6880 - accuracy: 0.1587 - val_loss: 3.6500 - val_accuracy: 0.1745
# Epoch 170/200
# 750/750 - 10s - loss: 3.6857 - accuracy: 0.1614 - val_loss: 3.6619 - val_accuracy: 0.1720
# Epoch 171/200
# 750/750 - 10s - loss: 3.6787 - accuracy: 0.1606 - val_loss: 3.6436 - val_accuracy: 0.1755
# Epoch 172/200
# 750/750 - 10s - loss: 3.6727 - accuracy: 0.1619 - val_loss: 3.6575 - val_accuracy: 0.1700
# Epoch 173/200
# 750/750 - 10s - loss: 3.6786 - accuracy: 0.1599 - val_loss: 3.6356 - val_accuracy: 0.1735
# Epoch 174/200
# 750/750 - 10s - loss: 3.6764 - accuracy: 0.1604 - val_loss: 3.6371 - val_accuracy: 0.1755
# Epoch 175/200
# 750/750 - 10s - loss: 3.6729 - accuracy: 0.1639 - val_loss: 3.6468 - val_accuracy: 0.1730
# Epoch 176/200
# 750/750 - 10s - loss: 3.6674 - accuracy: 0.1622 - val_loss: 3.6271 - val_accuracy: 0.1760
# Epoch 177/200
# 750/750 - 10s - loss: 3.6643 - accuracy: 0.1645 - val_loss: 3.6460 - val_accuracy: 0.1760
# Epoch 178/200
# 750/750 - 10s - loss: 3.6600 - accuracy: 0.1629 - val_loss: 3.6297 - val_accuracy: 0.1750
# Epoch 179/200
# 750/750 - 10s - loss: 3.6531 - accuracy: 0.1639 - val_loss: 3.6473 - val_accuracy: 0.1725
# Epoch 180/200
# 750/750 - 10s - loss: 3.6532 - accuracy: 0.1651 - val_loss: 3.6459 - val_accuracy: 0.1745
# Epoch 181/200
# 750/750 - 10s - loss: 3.6510 - accuracy: 0.1634 - val_loss: 3.6197 - val_accuracy: 0.1735
# Epoch 182/200
# 750/750 - 10s - loss: 3.6510 - accuracy: 0.1623 - val_loss: 3.6255 - val_accuracy: 0.1780
# Epoch 183/200
# 750/750 - 10s - loss: 3.6504 - accuracy: 0.1665 - val_loss: 3.6141 - val_accuracy: 0.1770
# Epoch 184/200
# 750/750 - 10s - loss: 3.6365 - accuracy: 0.1676 - val_loss: 3.6163 - val_accuracy: 0.1800
# Epoch 185/200
# 750/750 - 10s - loss: 3.6396 - accuracy: 0.1670 - val_loss: 3.6115 - val_accuracy: 0.1795
# Epoch 186/200
# 750/750 - 10s - loss: 3.6293 - accuracy: 0.1683 - val_loss: 3.6049 - val_accuracy: 0.1800
# Epoch 187/200
# 750/750 - 10s - loss: 3.6364 - accuracy: 0.1664 - val_loss: 3.6119 - val_accuracy: 0.1800
# Epoch 188/200
# 750/750 - 10s - loss: 3.6291 - accuracy: 0.1680 - val_loss: 3.6071 - val_accuracy: 0.1820
# Epoch 189/200
# 750/750 - 10s - loss: 3.6255 - accuracy: 0.1696 - val_loss: 3.6007 - val_accuracy: 0.1795
# Epoch 190/200
# 750/750 - 10s - loss: 3.6287 - accuracy: 0.1706 - val_loss: 3.6098 - val_accuracy: 0.1795
# Epoch 191/200
# 750/750 - 10s - loss: 3.6233 - accuracy: 0.1688 - val_loss: 3.6021 - val_accuracy: 0.1775
# Epoch 192/200
# 750/750 - 10s - loss: 3.6206 - accuracy: 0.1695 - val_loss: 3.6006 - val_accuracy: 0.1785
# Epoch 193/200
# 750/750 - 10s - loss: 3.6167 - accuracy: 0.1703 - val_loss: 3.5999 - val_accuracy: 0.1795
# Epoch 194/200
# 750/750 - 10s - loss: 3.6217 - accuracy: 0.1706 - val_loss: 3.6015 - val_accuracy: 0.1835
# Epoch 195/200
# 750/750 - 10s - loss: 3.6135 - accuracy: 0.1696 - val_loss: 3.6037 - val_accuracy: 0.1805
# Epoch 196/200
# 750/750 - 10s - loss: 3.6135 - accuracy: 0.1717 - val_loss: 3.6131 - val_accuracy: 0.1810
# Epoch 197/200
# 750/750 - 10s - loss: 3.6062 - accuracy: 0.1726 - val_loss: 3.5749 - val_accuracy: 0.1785
# Epoch 198/200
# 750/750 - 10s - loss: 3.6093 - accuracy: 0.1706 - val_loss: 3.6018 - val_accuracy: 0.1800
# Epoch 199/200
# 750/750 - 10s - loss: 3.5976 - accuracy: 0.1736 - val_loss: 3.5744 - val_accuracy: 0.1830
# Epoch 200/200
# 750/750 - 10s - loss: 3.6066 - accuracy: 0.1705 - val_loss: 3.5767 - val_accuracy: 0.1845

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,7))

plt.plot(model.history.history['accuracy'],label = 'accuracy')
plt.plot(model.history.history['val_accuracy'],label = 'val accuracy')

plt.legend()
plt.show()
