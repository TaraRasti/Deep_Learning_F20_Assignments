# %% [markdown]
# <a href="https://colab.research.google.com/github/TaraRasti/Deep_Learning_F20_Assignments/blob/master/Assignment%208/dropout/cifar100_Adam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPool2D
from keras.layers.core import Dense,Activation,Dropout,Flatten
from keras.utils import np_utils
from keras import *
import tensorflow as tf
import os
from six.moves import cPickle as pickle
import platform
import numpy as np
 
def load_files(filenames):
    data = np.array([])
    labels = np.array([])
    for name in filenames:
        with open(name, 'rb') as f:
            mydict = pickle.load(f, encoding='latin1')
        label_func = lambda x: np.array(x['fine_labels'], dtype='int32')
        newlabels = label_func(mydict)
        if data.size:
            data = np.vstack([data, mydict['data']])
            labels = np.hstack([labels, newlabels])
        else:
            data = mydict['data']
            labels = newlabels
    data = np.reshape(data, [-1, 3, 32, 32], order='C')
    data = np.transpose(data, [0, 2, 3, 1])
    return data, labels

def load_CIFAR100(data_dir):
    train_files = ['train']
    train_files = [os.path.join(data_dir, f) for f in train_files]
    test_files = ['test']
    test_files = [os.path.join(data_dir, f) for f in test_files]
    num_classes = 100
    train_data, train_labels = load_files(train_files)
    test_data, test_labels = load_files(test_files)
    return train_data, train_labels, test_data, test_labels
 
def get_CIFAR100_data(val_size=2000):
    cifar100_dir = '/content/drive/MyDrive/cifar-100-python'
    x_train, y_train, x_test, y_test = load_CIFAR100(cifar100_dir)
    x_train, x_val = np.split(x_train,[x_train.shape[0]-val_size])
    y_train, y_val = np.split(y_train,[y_train.shape[0]-val_size])
    x_train = x_train.astype('float32')
    x_val = x_val.astype('float32')
    x_test = x_test.astype('float32')
    x_train /= 255
    x_val /= 255
    x_test /= 255
    return x_train, y_train, x_val, y_val, x_test, y_test
x_train, y_train, x_val, y_val, x_test, y_test = get_CIFAR100_data()
print('Train data shape: ', x_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', x_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', x_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (48000, 32, 32, 3)
# Train labels shape:  (48000,)
# Validation data shape:  (2000, 32, 32, 3)
# Validation labels shape:  (2000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
epochs =  100
verbose =  2
name = 'conv_clf'
x = input = keras.Input(shape=(32,32,3))
x = layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical")(input)
x = layers.experimental.preprocessing.RandomContrast(0.2)(x)
x = layers.experimental.preprocessing.RandomRotation(3)(x)
x = layers.Conv2D(64,4,activation='relu')(x)
x = layers.Conv2D(64,4,activation='relu',kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.MaxPool2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(128,3,activation='relu')(x)
x = layers.Conv2D(128,3,activation='relu',kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(256,3,activation='relu')(x)
x = layers.Conv2D(256,3,activation='relu',kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Flatten()(x)
x = layers.Dense(512,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(256,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
x = layers.Dropout(0.1)(x)
x = layers.Dense(128,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
output = layers.Dense(100,'softmax')(x)
model = keras.Model(inputs=input, outputs=output, name=name)
model.compile(loss=keras.losses.SparseCategoricalCrossentropy(),
            optimizer='Adam',
            metrics=['accuracy'])
model.fit(x = x_train, y = y_train,
          batch_size=64, epochs=epochs,
          verbose=verbose,validation_data=(x_val,y_val),
          validation_batch_size = 64)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0053s vs `on_train_batch_end` time: 0.0084s). Check your callbacks.
# 750/750 - 10s - loss: 4.5217 - accuracy: 0.0273 - val_loss: 4.3434 - val_accuracy: 0.0515
# Epoch 2/100
# 750/750 - 9s - loss: 4.2331 - accuracy: 0.0495 - val_loss: 4.2913 - val_accuracy: 0.0500
# Epoch 3/100
# 750/750 - 9s - loss: 4.1159 - accuracy: 0.0659 - val_loss: 4.2487 - val_accuracy: 0.0660
# Epoch 4/100
# 750/750 - 9s - loss: 4.0380 - accuracy: 0.0811 - val_loss: 4.3625 - val_accuracy: 0.0440
# Epoch 5/100
# 750/750 - 9s - loss: 3.9416 - accuracy: 0.0953 - val_loss: 4.1594 - val_accuracy: 0.0815
# Epoch 6/100
# 750/750 - 9s - loss: 3.8573 - accuracy: 0.1106 - val_loss: 3.8575 - val_accuracy: 0.1090
# Epoch 7/100
# 750/750 - 9s - loss: 3.7681 - accuracy: 0.1262 - val_loss: 3.7389 - val_accuracy: 0.1400
# Epoch 8/100
# 750/750 - 9s - loss: 3.7039 - accuracy: 0.1381 - val_loss: 3.8672 - val_accuracy: 0.1385
# Epoch 9/100
# 750/750 - 9s - loss: 3.6385 - accuracy: 0.1514 - val_loss: 3.5619 - val_accuracy: 0.1670
# Epoch 10/100
# 750/750 - 9s - loss: 3.5782 - accuracy: 0.1643 - val_loss: 3.5594 - val_accuracy: 0.1775
# Epoch 11/100
# 750/750 - 9s - loss: 3.5237 - accuracy: 0.1758 - val_loss: 3.5585 - val_accuracy: 0.1700
# Epoch 12/100
# 750/750 - 9s - loss: 3.4741 - accuracy: 0.1807 - val_loss: 3.6478 - val_accuracy: 0.1715
# Epoch 13/100
# 750/750 - 10s - loss: 3.4333 - accuracy: 0.1910 - val_loss: 3.8358 - val_accuracy: 0.1430
# Epoch 14/100
# 750/750 - 9s - loss: 3.3940 - accuracy: 0.2008 - val_loss: 3.4882 - val_accuracy: 0.1870
# Epoch 15/100
# 750/750 - 9s - loss: 3.3505 - accuracy: 0.2092 - val_loss: 3.3451 - val_accuracy: 0.2070
# Epoch 16/100
# 750/750 - 10s - loss: 3.3127 - accuracy: 0.2169 - val_loss: 3.3875 - val_accuracy: 0.2145
# Epoch 17/100
# 750/750 - 10s - loss: 3.2705 - accuracy: 0.2239 - val_loss: 3.5061 - val_accuracy: 0.1995
# Epoch 18/100
# 750/750 - 10s - loss: 3.2362 - accuracy: 0.2314 - val_loss: 3.2215 - val_accuracy: 0.2280
# Epoch 19/100
# 750/750 - 10s - loss: 3.1924 - accuracy: 0.2417 - val_loss: 3.2609 - val_accuracy: 0.2255
# Epoch 20/100
# 750/750 - 10s - loss: 3.1624 - accuracy: 0.2512 - val_loss: 3.5738 - val_accuracy: 0.1885
# Epoch 21/100
# 750/750 - 10s - loss: 3.1326 - accuracy: 0.2552 - val_loss: 3.5880 - val_accuracy: 0.1990
# Epoch 22/100
# 750/750 - 10s - loss: 3.0930 - accuracy: 0.2654 - val_loss: 3.3752 - val_accuracy: 0.2175
# Epoch 23/100
# 750/750 - 10s - loss: 3.0598 - accuracy: 0.2709 - val_loss: 3.1063 - val_accuracy: 0.2605
# Epoch 24/100
# 750/750 - 10s - loss: 3.0389 - accuracy: 0.2754 - val_loss: 3.4366 - val_accuracy: 0.2325
# Epoch 25/100
# 750/750 - 10s - loss: 3.0075 - accuracy: 0.2837 - val_loss: 3.2429 - val_accuracy: 0.2485
# Epoch 26/100
# 750/750 - 10s - loss: 2.9805 - accuracy: 0.2885 - val_loss: 3.2402 - val_accuracy: 0.2425
# Epoch 27/100
# 750/750 - 10s - loss: 2.9594 - accuracy: 0.2945 - val_loss: 3.3499 - val_accuracy: 0.2320
# Epoch 28/100
# 750/750 - 10s - loss: 2.9337 - accuracy: 0.3019 - val_loss: 3.3113 - val_accuracy: 0.2415
# Epoch 29/100
# 750/750 - 10s - loss: 2.9144 - accuracy: 0.3053 - val_loss: 3.2799 - val_accuracy: 0.2475
# Epoch 30/100
# 750/750 - 10s - loss: 2.9023 - accuracy: 0.3081 - val_loss: 3.1852 - val_accuracy: 0.2605
# Epoch 31/100
# 750/750 - 10s - loss: 2.8796 - accuracy: 0.3175 - val_loss: 3.1507 - val_accuracy: 0.2675
# Epoch 32/100
# 750/750 - 10s - loss: 2.8626 - accuracy: 0.3176 - val_loss: 3.1109 - val_accuracy: 0.2720
# Epoch 33/100
# 750/750 - 10s - loss: 2.8394 - accuracy: 0.3248 - val_loss: 3.0443 - val_accuracy: 0.2825
# Epoch 34/100
# 750/750 - 10s - loss: 2.8208 - accuracy: 0.3303 - val_loss: 2.9965 - val_accuracy: 0.3035
# Epoch 35/100
# 750/750 - 10s - loss: 2.8158 - accuracy: 0.3335 - val_loss: 3.0828 - val_accuracy: 0.2965
# Epoch 36/100
# 750/750 - 10s - loss: 2.7872 - accuracy: 0.3381 - val_loss: 3.0984 - val_accuracy: 0.2955
# Epoch 37/100
# 750/750 - 10s - loss: 2.7703 - accuracy: 0.3413 - val_loss: 2.9543 - val_accuracy: 0.3155
# Epoch 38/100
# 750/750 - 10s - loss: 2.7633 - accuracy: 0.3462 - val_loss: 3.0811 - val_accuracy: 0.2855
# Epoch 39/100
# 750/750 - 10s - loss: 2.7427 - accuracy: 0.3488 - val_loss: 3.0835 - val_accuracy: 0.2910
# Epoch 40/100
# 750/750 - 10s - loss: 2.7411 - accuracy: 0.3494 - val_loss: 3.0289 - val_accuracy: 0.3035
# Epoch 41/100
# 750/750 - 10s - loss: 2.7182 - accuracy: 0.3535 - val_loss: 3.0270 - val_accuracy: 0.3005
# Epoch 42/100
# 750/750 - 10s - loss: 2.7113 - accuracy: 0.3584 - val_loss: 2.9385 - val_accuracy: 0.3150
# Epoch 43/100
# 750/750 - 10s - loss: 2.7011 - accuracy: 0.3587 - val_loss: 3.1668 - val_accuracy: 0.2800
# Epoch 44/100
# 750/750 - 10s - loss: 2.6823 - accuracy: 0.3643 - val_loss: 2.8405 - val_accuracy: 0.3380
# Epoch 45/100
# 750/750 - 10s - loss: 2.6725 - accuracy: 0.3662 - val_loss: 2.9553 - val_accuracy: 0.3175
# Epoch 46/100
# 750/750 - 10s - loss: 2.6617 - accuracy: 0.3707 - val_loss: 3.1031 - val_accuracy: 0.2935
# Epoch 47/100
# 750/750 - 10s - loss: 2.6426 - accuracy: 0.3722 - val_loss: 3.0622 - val_accuracy: 0.3005
# Epoch 48/100
# 750/750 - 10s - loss: 2.6433 - accuracy: 0.3745 - val_loss: 2.9937 - val_accuracy: 0.3150
# Epoch 49/100
# 750/750 - 10s - loss: 2.6279 - accuracy: 0.3806 - val_loss: 2.9250 - val_accuracy: 0.3385
# Epoch 50/100
# 750/750 - 10s - loss: 2.6231 - accuracy: 0.3801 - val_loss: 2.8076 - val_accuracy: 0.3505
# Epoch 51/100
# 750/750 - 10s - loss: 2.6065 - accuracy: 0.3847 - val_loss: 2.8997 - val_accuracy: 0.3325
# Epoch 52/100
# 750/750 - 10s - loss: 2.6021 - accuracy: 0.3845 - val_loss: 2.8455 - val_accuracy: 0.3430
# Epoch 53/100
# 750/750 - 10s - loss: 2.5929 - accuracy: 0.3888 - val_loss: 3.1496 - val_accuracy: 0.3005
# Epoch 54/100
# 750/750 - 10s - loss: 2.5788 - accuracy: 0.3938 - val_loss: 2.9430 - val_accuracy: 0.3270
# Epoch 55/100
# 750/750 - 10s - loss: 2.5690 - accuracy: 0.3928 - val_loss: 3.0907 - val_accuracy: 0.3160
# Epoch 56/100
# 750/750 - 10s - loss: 2.5635 - accuracy: 0.3975 - val_loss: 2.9659 - val_accuracy: 0.3185
# Epoch 57/100
# 750/750 - 10s - loss: 2.5591 - accuracy: 0.3980 - val_loss: 2.9151 - val_accuracy: 0.3290
# Epoch 58/100
# 750/750 - 10s - loss: 2.5490 - accuracy: 0.3985 - val_loss: 2.8524 - val_accuracy: 0.3380
# Epoch 59/100
# 750/750 - 10s - loss: 2.5436 - accuracy: 0.4009 - val_loss: 2.8642 - val_accuracy: 0.3525
# Epoch 60/100
# 750/750 - 10s - loss: 2.5280 - accuracy: 0.4069 - val_loss: 2.9042 - val_accuracy: 0.3310
# Epoch 61/100
# 750/750 - 10s - loss: 2.5219 - accuracy: 0.4051 - val_loss: 2.8947 - val_accuracy: 0.3375
# Epoch 62/100
# 750/750 - 10s - loss: 2.5156 - accuracy: 0.4075 - val_loss: 3.1169 - val_accuracy: 0.3135
# Epoch 63/100
# 750/750 - 10s - loss: 2.5144 - accuracy: 0.4051 - val_loss: 2.9043 - val_accuracy: 0.3515
# Epoch 64/100
# 750/750 - 10s - loss: 2.5039 - accuracy: 0.4121 - val_loss: 2.9325 - val_accuracy: 0.3440
# Epoch 65/100
# 750/750 - 10s - loss: 2.5009 - accuracy: 0.4146 - val_loss: 2.7962 - val_accuracy: 0.3555
# Epoch 66/100
# 750/750 - 10s - loss: 2.4930 - accuracy: 0.4117 - val_loss: 2.9900 - val_accuracy: 0.3280
# Epoch 67/100
# 750/750 - 10s - loss: 2.4878 - accuracy: 0.4164 - val_loss: 2.9581 - val_accuracy: 0.3285
# Epoch 68/100
# 750/750 - 10s - loss: 2.4724 - accuracy: 0.4207 - val_loss: 2.8424 - val_accuracy: 0.3565
# Epoch 69/100
# 750/750 - 10s - loss: 2.4706 - accuracy: 0.4213 - val_loss: 2.8071 - val_accuracy: 0.3615
# Epoch 70/100
# 750/750 - 10s - loss: 2.4666 - accuracy: 0.4208 - val_loss: 2.7586 - val_accuracy: 0.3665
# Epoch 71/100
# 750/750 - 10s - loss: 2.4512 - accuracy: 0.4233 - val_loss: 3.0166 - val_accuracy: 0.3390
# Epoch 72/100
# 750/750 - 10s - loss: 2.4538 - accuracy: 0.4246 - val_loss: 2.9426 - val_accuracy: 0.3345
# Epoch 73/100
# 750/750 - 10s - loss: 2.4463 - accuracy: 0.4287 - val_loss: 2.8580 - val_accuracy: 0.3630
# Epoch 74/100
# 750/750 - 10s - loss: 2.4415 - accuracy: 0.4291 - val_loss: 2.7418 - val_accuracy: 0.3695
# Epoch 75/100
# 750/750 - 10s - loss: 2.4379 - accuracy: 0.4299 - val_loss: 2.8229 - val_accuracy: 0.3545
# Epoch 76/100
# 750/750 - 10s - loss: 2.4266 - accuracy: 0.4298 - val_loss: 2.7644 - val_accuracy: 0.3860
# Epoch 77/100
# 750/750 - 10s - loss: 2.4219 - accuracy: 0.4322 - val_loss: 2.7301 - val_accuracy: 0.3905
# Epoch 78/100
# 750/750 - 10s - loss: 2.4235 - accuracy: 0.4327 - val_loss: 2.8705 - val_accuracy: 0.3580
# Epoch 79/100
# 750/750 - 10s - loss: 2.4157 - accuracy: 0.4368 - val_loss: 2.8446 - val_accuracy: 0.3530
# Epoch 80/100
# 750/750 - 10s - loss: 2.4070 - accuracy: 0.4356 - val_loss: 2.7282 - val_accuracy: 0.3735
# Epoch 81/100
# 750/750 - 10s - loss: 2.4064 - accuracy: 0.4352 - val_loss: 2.8107 - val_accuracy: 0.3615
# Epoch 82/100
# 750/750 - 10s - loss: 2.4005 - accuracy: 0.4398 - val_loss: 2.9387 - val_accuracy: 0.3510
# Epoch 83/100
# 750/750 - 10s - loss: 2.3972 - accuracy: 0.4404 - val_loss: 2.7607 - val_accuracy: 0.3655
# Epoch 84/100
# 750/750 - 10s - loss: 2.3926 - accuracy: 0.4428 - val_loss: 2.7269 - val_accuracy: 0.3750
# Epoch 85/100
# 750/750 - 10s - loss: 2.3954 - accuracy: 0.4428 - val_loss: 2.7568 - val_accuracy: 0.3745
# Epoch 86/100
# 750/750 - 10s - loss: 2.3835 - accuracy: 0.4413 - val_loss: 2.8013 - val_accuracy: 0.3520
# Epoch 87/100
# 750/750 - 10s - loss: 2.3775 - accuracy: 0.4439 - val_loss: 2.8336 - val_accuracy: 0.3720
# Epoch 88/100
# 750/750 - 10s - loss: 2.3721 - accuracy: 0.4472 - val_loss: 2.6223 - val_accuracy: 0.3940
# Epoch 89/100
# 750/750 - 10s - loss: 2.3682 - accuracy: 0.4472 - val_loss: 2.7964 - val_accuracy: 0.3710
# Epoch 90/100
# 750/750 - 10s - loss: 2.3578 - accuracy: 0.4500 - val_loss: 2.7716 - val_accuracy: 0.3775
# Epoch 91/100
# 750/750 - 10s - loss: 2.3615 - accuracy: 0.4496 - val_loss: 2.7471 - val_accuracy: 0.3815
# Epoch 92/100
# 750/750 - 10s - loss: 2.3572 - accuracy: 0.4482 - val_loss: 2.8277 - val_accuracy: 0.3585
# Epoch 93/100
# 750/750 - 10s - loss: 2.3529 - accuracy: 0.4485 - val_loss: 2.6309 - val_accuracy: 0.3935
# Epoch 94/100
# 750/750 - 10s - loss: 2.3475 - accuracy: 0.4506 - val_loss: 2.9026 - val_accuracy: 0.3535
# Epoch 95/100
# 750/750 - 10s - loss: 2.3440 - accuracy: 0.4531 - val_loss: 2.7215 - val_accuracy: 0.3855
# Epoch 96/100
# 750/750 - 10s - loss: 2.3390 - accuracy: 0.4563 - val_loss: 2.7206 - val_accuracy: 0.3910
# Epoch 97/100
# 750/750 - 10s - loss: 2.3420 - accuracy: 0.4559 - val_loss: 2.6963 - val_accuracy: 0.3870
# Epoch 98/100
# 750/750 - 10s - loss: 2.3377 - accuracy: 0.4565 - val_loss: 2.8485 - val_accuracy: 0.3755
# Epoch 99/100
# 750/750 - 10s - loss: 2.3344 - accuracy: 0.4554 - val_loss: 2.6999 - val_accuracy: 0.3920
# Epoch 100/100
# 750/750 - 10s - loss: 2.3276 - accuracy: 0.4581 - val_loss: 2.7973 - val_accuracy: 0.3720

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,7))

plt.plot(model.history.history['accuracy'],label = 'accuracy')
plt.plot(model.history.history['val_accuracy'],label = 'val accuracy')

plt.legend()
plt.show()
